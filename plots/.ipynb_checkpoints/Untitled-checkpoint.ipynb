# %%
# %matplotlib inline

import datetime
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import requests

# %%
r = requests.get('http://influx.dedovic.com:8086/query?q=select+value+from+temperature+where+time+%3E+now()+-+2d&db=readings')
json = r.json()
data = json['results'][0]['series'][0]['values']

dates = [datetime.datetime.strptime(x[0], '%Y-%m-%dT%H:%M:%SZ') for x in data]
values = [x[1] * 1.8 + 32 for x in data]
plt.plot(dates, values)
# print values
